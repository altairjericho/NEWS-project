# %%
import numpy as np
import pandas as pd
from datetime import datetime
import os
import shutil
import re
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from skimage.transform import rotate

import keras
from keras.layers import Input, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, MaxPooling2D, Dropout
from keras.layers import ZeroPadding3D, Conv3D, MaxPooling3D
from keras import optimizers
from keras.models import Model

import tensorflow as tf
import keras.backend as K
K.set_image_data_format('channels_last')

# %matplotlib inline
# Out:
# /home/scanner-ml/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
from tensorflow.python.client import device_lib
# TensorFlow wizardry
config = tf.ConfigProto() 
# Don't pre-allocate memory; allocate as-needed
config.gpu_options.allow_growth = True 
# Only allow a total of half the GPU memory to be allocated
#config.gpu_options.per_process_gpu_memory_fraction = 0.5 
# Create a session with the above options specified.
K.tensorflow_backend.set_session(tf.Session(config=config))

# %%
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 9272321176927684337
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 1485832192
# locality {
#   bus_id: 1
# }
# incarnation: 7445690712092811218
# physical_device_desc: "device: 0, name: GeForce GTX 780, pci bus id: 0000:03:00.0, compute capability: 3.5"
# ]

# %%
path = "/mnt/ML-drive/scanner-ml/Artem/share/Valerio/"
class_names = ['C100keV','TestSample']
n_pols = 8

# %%
def load_images(path, name_dir='TestSample', n_pols=8):
    
    img_ind = []
    path = path+name_dir+"/crops/"
    img_names = os.listdir(path)
    for name in img_names:
        img_ind.append(re.split('[_.]',name))
    img_ind = pd.DataFrame(np.array(img_ind),columns=['ViewID','gr','GrainID','pol','Polarization','cl','ClusterID','csv'])
    img_ind = img_ind.drop(['csv'],axis=1).sort_values(['ViewID','GrainID','Polarization'])
    for view in np.unique(img_ind['ViewID']):
        view_imgs = img_ind[ img_ind['ViewID']==view ]
        for grain in np.unique(view_imgs['GrainID']):
            grain_imgs = view_imgs[ view_imgs['GrainID']==grain ]
            if grain_imgs.shape[0]!=8:
                img_ind = img_ind.drop(grain_imgs.index)
    img_names = []
    for name in img_ind.values:
        img_names.append('_'.join(name)+'.csv')
    
    i=0
    im_array = []
    for name in img_names:
        if i==0 : tmp_im = []
        tmp_im.append(pd.read_csv(path+name, header=None).drop(31, axis=1).values)
        i+=1
        if i==n_pols:
            im_array.append(np.array(tmp_im).T)
            i=0
    return np.array(im_array)

# %%
def plot_hist(history, span=5, names=['acc','loss']):
    plt.figure(figsize=(8,6))
    plt.title('Training accuracy')
    plt.plot(history['acc'], "g:", label='Train')
    plt.plot(history['val_acc'], "r:", label='Validation')
    plt.plot(pd.ewma(np.array(history['acc']),span=span), "g", label='Smoothed train')
    plt.plot(pd.ewma(np.array(history['val_acc']),span=span), "r", label='Smoothed validation')
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.grid()
    plt.legend()
    plt.savefig(names[0]+'.pdf')
    plt.show()
    
    plt.figure(figsize=(8,6))
    plt.title('Training loss')
    plt.plot(history['loss'], "g:", label='Train')
    plt.plot(history['val_loss'], "r:", label='Validation')
    plt.plot(pd.ewma(np.array(history['loss']),span=span), "g", label='Smoothed train')
    plt.plot(pd.ewma(np.array(history['val_loss']),span=span), "r", label='Smoothed validation')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.grid()
    plt.legend()
    plt.savefig(names[1]+'.pdf')
    plt.show()
    return None

# %%
# %%time
X_sign = load_images(path, 'C100keV')
y_sign = np.ones((X_sign.shape[0],1))
X_noise = load_images(path, 'TestSample')
y_noise = np.zeros((X_noise.shape[0],1))

X = np.vstack((X_sign, X_noise))
y = np.vstack((y_sign, y_noise))

X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size=0.15, stratify=y)

# Normalize image vectors (????)
#X_train = X_train_orig/255.
#X_test = X_test_orig/255.

print ("number of training examples = " + str(X_train.shape[0]))
print ("number of test examples = " + str(X_test.shape[0]))
print ("X_train shape: " + str(X_train.shape))
print ("Y_train shape: " + str(Y_train.shape))
print ("X_test shape: " + str(X_test.shape))
print ("Y_test shape: " + str(Y_test.shape))
# Out:
# number of training examples = 19703
# number of test examples = 3478
# X_train shape: (19703, 31, 31, 8)
# Y_train shape: (19703, 1)
# X_test shape: (3478, 31, 31, 8)
# Y_test shape: (3478, 1)
# CPU times: user 8min 31s, sys: 7.12 s, total: 8min 38s
# Wall time: 8min 33s

# %%
# %%time

X_ddd_train = np.array([X_train.T]).T
X_ddd_test = np.array([X_test.T]).T

print ("X_3d_train shape: " + str(X_ddd_train.shape))
print ("Y_train shape: " + str(Y_train.shape))
print ("X_3d_test shape: " + str(X_ddd_test.shape))
print ("Y_test shape: " + str(Y_test.shape))
# Out:
# X_3d_train shape: (19703, 31, 31, 8, 1)
# Y_train shape: (19703, 1)
# X_3d_test shape: (3478, 31, 31, 8, 1)
# Y_test shape: (3478, 1)
# CPU times: user 2.73 s, sys: 417 ms, total: 3.15 s
# Wall time: 3.11 s

# %% [markdown]
# # VGG 3D

# %%
def DDD_VGG_model(input_shape=(31,31,8,1), classes=2):
    
    
    X_input = Input(input_shape)

    X = Conv3D(64, 3, padding='same', activation='relu', name='conv1_1')(X_input)
    X = Conv3D(64, 3, padding='same', name='conv1_2')(X)
    #X = BatchNormalization(name='batch1')(X)
    X = Activation('relu')(X)
    X = MaxPooling3D(name='pool1')(X)
    print('conv1\t',X.get_shape())
    
    X = Conv3D(128, 3, padding='same', name='conv2')(X)
    #X = BatchNormalization(name='batch2')(X)
    X = Activation('relu')(X)
    X = MaxPooling3D(name='pool2')(X)
    print('conv2\t',X.get_shape())
    
    X = Dropout(rate=0.5, name='drop_middle')(X)
    
    X = Conv3D(256, 3, padding='same', name='conv3')(X)
    #X = BatchNormalization(name='batch3')(X)
    X = Activation('relu')(X)
    X = MaxPooling3D(name='pool3')(X)
    print('conv3\t',X.get_shape())
    
    X = Conv3D(256, 3, padding='same', name='conv4')(X)
    #X = BatchNormalization(name='batch4')(X)
    X = Activation('relu')(X)
    X = MaxPooling3D(padding='same', name='pool4')(X)
    print('conv4\t',X.get_shape())
    
    X = Dropout(rate=0.5, name='drop')(X)
    
    X = Flatten()(X)
    X = Dense(1, activation='sigmoid', name='fc')(X)
    if classes != 2 : print('oh no, too many classes, change the model output to softmax!')
    
    model = Model(inputs = X_input, outputs = X, name='3D_VGG_model')
    return model

# %%
ddd_vgg_model = DDD_VGG_model(input_shape=(31,31,8,1))
# Out:
# conv1	 (?, 15, 15, 4, 64)
# conv2	 (?, 7, 7, 2, 128)
# conv3	 (?, 3, 3, 1, 256)
# conv4	 (?, 2, 2, 1, 256)

# %%
ddd_vgg_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Epoch 99/100
#  - 143s - loss: 0.1490 - acc: 0.9421 - val_loss: 0.2217 - val_acc: 0.9171
# Epoch 100/100
#  - 143s - loss: 0.1433 - acc: 0.9448 - val_loss: 0.1699 - val_acc: 0.9374

# %%
preds = ddd_vgg_model.evaluate(X_ddd_test, Y_test)
print ("Loss = " + str(preds[0]))
print ("Test Accuracy = " + str(preds[1]))
print (preds)
# Out:
# 3478/3478 [==============================] - 11s 3ms/step
# Loss = 0.16570592040539886
# Test Accuracy = 0.9378953420478355
# [0.16570592040539886, 0.9378953420478355]

# %%
plot_hist(vgg_hist[0].history, span=5)
# Out:
# /home/scanner-ml/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: pd.ewm_mean is deprecated for ndarrays and will be removed in a future version
#   """
# /home/scanner-ml/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: FutureWarning: pd.ewm_mean is deprecated for ndarrays and will be removed in a future version
# /home/scanner-ml/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:16: FutureWarning: pd.ewm_mean is deprecated for ndarrays and will be removed in a future version
#   app.launch_new_instance()
# /home/scanner-ml/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:17: FutureWarning: pd.ewm_mean is deprecated for ndarrays and will be removed in a future version

# %%
vgg_hist = [vgg_hist]

# %% [markdown]
# ## Tuning the learning rate

# %%
adamka = optimizers.Adam(lr=1e-5)
ddd_vgg_model = DDD_VGG_model(input_shape=(31,31,8,1))
ddd_vgg_model.compile(optimizer=adamka, loss='binary_crossentropy', metrics=['accuracy'])
vgg_hist.append(ddd_vgg_model.fit(X_ddd_train, Y_train, epochs = 100, batch_size = 128, validation_split=0.15, verbose=2))
# Out:
# conv1	 (?, 15, 15, 4, 64)
# conv2	 (?, 7, 7, 2, 128)
# conv3	 (?, 3, 3, 1, 256)
# conv4	 (?, 2, 2, 1, 256)
# Train on 16747 samples, validate on 2956 samples
# Epoch 1/100
#  - 143s - loss: 0.6216 - acc: 0.6823 - val_loss: 0.6183 - val_acc: 0.6861
# Epoch 2/100
#  - 143s - loss: 0.6053 - acc: 0.6886 - val_loss: 0.6163 - val_acc: 0.6861
# Epoch 3/100
#  - 143s - loss: 0.5944 - acc: 0.6896 - val_loss: 0.6052 - val_acc: 0.6861
# Epoch 4/100
#  - 143s - loss: 0.5866 - acc: 0.6897 - val_loss: 0.5901 - val_acc: 0.6861
# Epoch 5/100
#  - 143s - loss: 0.5769 - acc: 0.6930 - val_loss: 0.5738 - val_acc: 0.6962
# Epoch 6/100
#  - 143s - loss: 0.5638 - acc: 0.6993 - val_loss: 0.5563 - val_acc: 0.7043
# Epoch 7/100
#  - 143s - loss: 0.5537 - acc: 0.7118 - val_loss: 0.5418 - val_acc: 0.7229
# Epoch 8/100
#  - 143s - loss: 0.5405 - acc: 0.7291 - val_loss: 0.5294 - val_acc: 0.7277
# Epoch 9/100
#  - 143s - loss: 0.5283 - acc: 0.7430 - val_loss: 0.5179 - val_acc: 0.7588
# Epoch 10/100
#  - 143s - loss: 0.5122 - acc: 0.7615 - val_loss: 0.5035 - val_acc: 0.7388
# Epoch 11/100
#  - 143s - loss: 0.4934 - acc: 0.7706 - val_loss: 0.4805 - val_acc: 0.7629
# Epoch 89/100
#  - 148s - loss: 0.1691 - acc: 0.9331 - val_loss: 0.1694 - val_acc: 0.9317
# Epoch 90/100
#  - 148s - loss: 0.1703 - acc: 0.9320 - val_loss: 0.1549 - val_acc: 0.9425
# Epoch 91/100
#  - 148s - loss: 0.1725 - acc: 0.9320 - val_loss: 0.1735 - val_acc: 0.9266
# Epoch 92/100
#  - 148s - loss: 0.1614 - acc: 0.9365 - val_loss: 0.1513 - val_acc: 0.9432
# Epoch 93/100
#  - 148s - loss: 0.1652 - acc: 0.9353 - val_loss: 0.1505 - val_acc: 0.9459
# Epoch 94/100
#  - 148s - loss: 0.1606 - acc: 0.9353 - val_loss: 0.1795 - val_acc: 0.9273
# Epoch 95/100
#  - 148s - loss: 0.1653 - acc: 0.9343 - val_loss: 0.1571 - val_acc: 0.9398
# Epoch 96/100
#  - 148s - loss: 0.1725 - acc: 0.9313 - val_loss: 0.1554 - val_acc: 0.9428
# Epoch 97/100
#  - 148s - loss: 0.1588 - acc: 0.9364 - val_loss: 0.1513 - val_acc: 0.9411
# Epoch 98/100
#  - 148s - loss: 0.1677 - acc: 0.9322 - val_loss: 0.1702 - val_acc: 0.9327
# Epoch 99/100
#  - 148s - loss: 0.1670 - acc: 0.9338 - val_loss: 0.1740 - val_acc: 0.9323
# Epoch 100/100
#  - 148s - loss: 0.1622 - acc: 0.9355 - val_loss: 0.1569 - val_acc: 0.9398

# %%
plot_hist(vgg_hist[-1].history, span=5)
# Out:
# /home/scanner-ml/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: pd.ewm_mean is deprecated for ndarrays and will be removed in a future version
#   """
# /home/scanner-ml/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: FutureWarning: pd.ewm_mean is deprecated for ndarrays and will be removed in a future version
# /home/scanner-ml/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:16: FutureWarning: pd.ewm_mean is deprecated for ndarrays and will be removed in a future version
#   app.launch_new_instance()
# /home/scanner-ml/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:17: FutureWarning: pd.ewm_mean is deprecated for ndarrays and will be removed in a future version

# %%
plt.figure(figsize=(6,4))
plt.title('Validation accuracy')
plt.plot(vgg_hist[-1].history['val_acc'], "b:", label='Accuracy')
plt.plot(pd.ewma(np.array(vgg_hist[-1].history['val_acc']),span=5), "r", label='Smoothed accuracy')
plt.xlabel('#iteration')
plt.ylabel('accuracy')
plt.legend()
plt.grid()
plt.savefig('acc.pdf')
plt.show()
# Out:
# /home/scanner-ml/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: FutureWarning: pd.ewm_mean is deprecated for ndarrays and will be removed in a future version
#   after removing the cwd from sys.path.

# %%
vgg_hist
# Out:
# [<keras.callbacks.History at 0x7fac9a914828>,
#  <keras.callbacks.History at 0x7fab6d582cc0>]

# %% [markdown]
# #### Learning rate with decay

# %%
adamka = optimizers.Adam(lr=1e-5, decay=1e-7)
ddd_vgg_model = DDD_VGG_model(input_shape=(31,31,8,1))
ddd_vgg_model.compile(optimizer=adamka, loss='binary_crossentropy', metrics=['accuracy'])
vgg_hist.append(ddd_vgg_model.fit(X_ddd_train, Y_train, epochs = 100, batch_size = 128, validation_split=0.15, verbose=2))
# Out:
anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: pd.ewm_mean is deprecated for ndarrays and will be removed in a future version
#   """
# /home/scanner-ml/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: FutureWarning: pd.ewm_mean is deprecated for ndarrays and will be removed in a future version
# /home/scanner-ml/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:16: FutureWarning: pd.ewm_mean is deprecated for ndarrays and will be removed in a future version
#   app.launch_new_instance()
# /home/scanner-ml/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:17: FutureWarning: pd.ewm_mean is deprecated for ndarrays and will be removed in a future version

# %% [markdown]
# # VGG 3D II

# %%
vgg_II_hist = []

# %%
def DDD_VGG_II_model(input_shape=(31,31,8,1), classes=2):
    
    
    X_input = Input(input_shape)

    X = Conv3D(64, 3, padding='same', activation='relu', name='conv1_1')(X_input)
    X = Conv3D(64, 3, padding='same', name='conv1_2')(X)
    #X = BatchNormalization(name='batch1')(X)
    X = Activation('relu')(X)
    X = MaxPooling3D(name='pool1')(X)
    #print('conv1\t',X.get_shape())
    
    X = Conv3D(128, 3, padding='same', name='conv2')(X)
    #X = BatchNormalization(name='batch2')(X)
    X = Activation('relu')(X)
    X = MaxPooling3D(name='pool2')(X)
    #print('conv2\t',X.get_shape())
    
    X = Dropout(rate=0.5, name='drop_middle')(X)
    
    X = Conv3D(256, 3, padding='same', name='conv3')(X)
    #X = BatchNormalization(name='batch3')(X)
    X = Activation('relu')(X)
    X = MaxPooling3D(name='pool3')(X)
    #print('conv3\t',X.get_shape())
    
    X = Conv3D(512, 3, padding='same', name='conv4')(X)
    #X = BatchNormalization(name='batch4')(X)
    X = Activation('relu')(X)
    X = MaxPooling3D(padding='same', name='pool4')(X)
    #print('conv4\t',X.get_shape())
    
    X = Dropout(rate=0.5, name='drop')(X)
    
    X = Flatten()(X)
    X = Dense(1, activation='sigmoid', name='class')(X)
    if classes != 2 : print('oh no, too many classes, change the model output to softmax!')
    
    model = Model(inputs = X_input, outputs = X, name='3D_VGG_model')
    return model

# %%
adamka = optimizers.Adam(lr=1e-5)
ddd_vgg_model = DDD_VGG_II_model(input_shape=(31,31,8,1))
ddd_vgg_model.compile(optimizer=adamka, loss='binary_crossentropy', metrics=['accuracy'])
vgg_II_hist.append(ddd_vgg_model.fit(X_ddd_train, Y_train, epochs = 100, batch_size = 128, validation_split=0.15, verbose=2))
# Out:
# conv1	 (?, 15, 15, 4, 64)
# conv2	 (?, 7, 7, 2, 128)
# conv3	 (?, 3, 3, 1, 256)
# conv4	 (?, 2, 2, 1, 512)
# Train on 16747 samples, validate on 2956 samples
# Epoch 1/100
#  - 160s - loss: 0.6520 - acc: 0.6629 - val_loss: 0.6370 - val_acc: 0.6861
# Epoch 2/100
#  - 158s - loss: 0.6084 - acc: 0.6883 - val_loss: 0.6167 - val_acc: 0.6861
# Epoch 3/100
#  - 158s - loss: 0.5965 - acc: 0.6894 - val_loss: 0.6264 - val_acc: 0.6915
# Epoch 4/100
#  - 158s - loss: 0.5880 - acc: 0.6902 - val_loss: 0.5982 - val_acc: 0.6884
# Epoch 5/100
#  - 158s - loss: 0.5807 - acc: 0.6942 - val_loss: 0.5920 - val_acc: 0.7470
# Epoch 6/100
# Epoch 83/100
#  - 158s - loss: 0.1896 - acc: 0.9233 - val_loss: 0.1738 - val_acc: 0.9306
# Epoch 84/100
#  - 158s - loss: 0.1860 - acc: 0.9243 - val_loss: 0.1738 - val_acc: 0.9327
# Epoch 85/100
#  - 158s - loss: 0.1868 - acc: 0.9268 - val_loss: 0.1723 - val_acc: 0.9381
# Epoch 86/100
#  - 158s - loss: 0.1841 - acc: 0.9273 - val_loss: 0.1905 - val_acc: 0.9212
# Epoch 87/100
#  - 158s - loss: 0.1899 - acc: 0.9233 - val_loss: 0.1755 - val_acc: 0.9340
# Epoch 88/100
#  - 158s - loss: 0.1867 - acc: 0.9257 - val_loss: 0.1743 - val_acc: 0.9347
# Epoch 89/100
#  - 158s - loss: 0.1781 - acc: 0.9301 - val_loss: 0.1689 - val_acc: 0.9347
# Epoch 90/100
#  - 158s - loss: 0.1820 - acc: 0.9251 - val_loss: 0.1734 - val_acc: 0.9327
# Epoch 91/100
#  - 158s - loss: 0.1841 - acc: 0.9291 - val_loss: 0.1863 - val_acc: 0.9252
# Epoch 92/100
#  - 158s - loss: 0.1865 - acc: 0.9249 - val_loss: 0.1715 - val_acc: 0.9357
# Epoch 93/100
#  - 158s - loss: 0.1826 - acc: 0.9269 - val_loss: 0.1662 - val_acc: 0.9384
# Epoch 94/100
#  - 158s - loss: 0.1779 - acc: 0.9283 - val_loss: 0.1658 - val_acc: 0.9388
# Epoch 95/100
#  - 158s - loss: 0.1857 - acc: 0.9253 - val_loss: 0.1719 - val_acc: 0.9334
# Epoch 96/100
#  - 158s - loss: 0.1801 - acc: 0.9264 - val_loss: 0.1637 - val_acc: 0.9405
# Epoch 97/100
#  - 158s - loss: 0.1785 - acc: 0.9301 - val_loss: 0.1716 - val_acc: 0.9337
# Epoch 98/100
#  - 158s - loss: 0.1778 - acc: 0.9296 - val_loss: 0.1694 - val_acc: 0.9354
# Epoch 99/100
#  - 158s - loss: 0.1772 - acc: 0.9299 - val_loss: 0.1621 - val_acc: 0.9381
# Epoch 100/100
#  - 158s - loss: 0.1752 - acc: 0.9291 - val_loss: 0.1646 - val_acc: 0.9408

# %%
plot_hist(vgg_II_hist[-1].history, span=5)
# Out:
# /home/scanner-ml/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: pd.ewm_mean is deprecated for ndarrays and will be removed in a future version
#   """
# /home/scanner-ml/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: FutureWarning: pd.ewm_mean is deprecated for ndarrays and will be removed in a future version
# /home/scanner-ml/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:16: FutureWarning: pd.ewm_mean is deprecated for ndarrays and will be removed in a future version
#   app.launch_new_instance()
# /home/scanner-ml/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:17: FutureWarning: pd.ewm_mean is deprecated for ndarrays and will be removed in a future version

# %%
preds = ddd_vgg_model.evaluate(X_ddd_test, Y_test)
print ("Loss = " + str(preds[0]))
print ("Test Accuracy = " + str(preds[1]))
print (preds)
# Out:
# 3478/3478 [==============================] - 12s 3ms/step
# Loss = 0.14900350914288005
# Test Accuracy = 0.9433582518688902
# [0.14900350914288005, 0.9433582518688902]

# %% [markdown]
# ## Varying number of training samples

# %%
vgg_samp = [0.1, 0.2, 0.4, 0.6]
vgg_samp_hist = []
pred_samp = []

# %%
vgg_samp_hist
# Out:
# []

# %%
samp = vgg_samp[0]
adamka = optimizers.Adam(lr=1e-4, decay=1e-6)
ddd_vgg_model = DDD_VGG_model(input_shape=(31,31,8,1))
ddd_vgg_model.compile(optimizer=adamka, loss='binary_crossentropy', metrics=['accuracy'])
vgg_samp_hist.append(ddd_vgg_model.fit(X_ddd_train, Y_train, epochs = 100, batch_size = 64, validation_split=1-samp, verbose=1))
    #print('training on ', vgg_samp_hist[-1].params['samples'], ' samples')
plot_hist(vgg_samp_hist[-1].history, span=5, names=['acc_'+str(round(samp*100))+'perc','loss_'+str(round(samp*100))+'perc'])
pred_samp.append(ddd_vgg_model.evaluate(X_ddd_test, Y_test))
# Out:
# conv1	 (?, 15, 15, 4, 64)
# conv2	 (?, 7, 7, 2, 128)
# conv3	 (?, 3, 3, 1, 256)
# conv4	 (?, 2, 2, 1, 256)
# Train on 1970 samples, validate on 17733 samples
# Epoch 1/100
# 1970/1970 [==============================] - 76s 39ms/step - loss: 0.6730 - acc: 0.6690 - val_loss: 0.6386 - val_acc: 0.6889
# Epoch 2/100
# 1970/1970 [==============================] - 73s 37ms/step - loss: 0.6102 - acc: 0.6873 - val_loss: 0.6278 - val_acc: 0.6889
# Epoch 3/100
# 1970/1970 [==============================] - 73s 37ms/step - loss: 0.6053 - acc: 0.6873 - val_loss: 0.6192 - val_acc: 0.6889
# Epoch 4/100
# 1970/1970 [==============================] - 73s 37ms/step - loss: 0.5967 - acc: 0.6873 - val_loss: 0.6001 - val_acc: 0.6889
# Epoch 5/100
# 1970/1970 [==============================] - 73s 37ms/step - loss: 0.5844 - acc: 0.6883 - val_loss: 0.6110 - val_acc: 0.7187
# Epoch 6/100
# 1970/1970 [==============================] - 73s 37ms/step - loss: 0.5753 - acc: 0.6929 - val_loss: 0.5677 - val_acc: 0.6892
# Epoch 7/100
# 1970/1970 [==============================] - 73s 37ms/step - loss: 0.5614 - acc: 0.7051 - val_loss: 0.5617 - val_acc: 0.7094
# Epoch 8/100
# 1970/1970 [==============================] - 73s 37ms/step - loss: 0.5456 - acc: 0.7198 - val_loss: 0.5489 - val_acc: 0.7207
# Epoch 9/100
# 1970/1970 [==============================] - 73s 37ms/step - loss: 0.5443 - acc: 0.7244 - val_loss: 0.5494 - val_acc: 0.7509
# Epoch 10/100
# 1970/1970 [==============================] - 73s 37ms/step - loss: 0.5373 - acc: 0.7330 - val_loss: 0.5377 - val_acc: 0.7409
# Epoch 11/100
# 1970/1970 [==============================] - 73s 37ms/step - loss: 0.5284 - acc: 0.7376 - val_loss: 0.5302 - val_acc: 0.7347
# Epoch 12/100
# 1970/1970 [==============================] - 73s 37ms/step - loss: 0.5260 - acc: 0.7396 - val_loss: 0.5296 - val_acc: 0.7271
# Epoch 13/100
# 1970/1970 [==============================] - 73s 37ms/step - loss: 0.5252 - acc: 0.7467 - val_loss: 0.5264 - val_acc: 0.7413
# Epoch 14/100
# Epoch 94/100
# 1970/1970 [==============================] - 73s 37ms/step - loss: 0.1542 - acc: 0.9396 - val_loss: 0.2363 - val_acc: 0.9067
# Epoch 95/100
# 1970/1970 [==============================] - 72s 37ms/step - loss: 0.1474 - acc: 0.9411 - val_loss: 0.2133 - val_acc: 0.9200
# Epoch 96/100
# 1970/1970 [==============================] - 73s 37ms/step - loss: 0.1527 - acc: 0.9426 - val_loss: 0.2658 - val_acc: 0.8969
# Epoch 97/100
# 1970/1970 [==============================] - 73s 37ms/step - loss: 0.1692 - acc: 0.9310 - val_loss: 0.2068 - val_acc: 0.9223
# Epoch 98/100
# 1970/1970 [==============================] - 73s 37ms/step - loss: 0.1507 - acc: 0.9411 - val_loss: 0.2096 - val_acc: 0.9209
# Epoch 99/100
# 1970/1970 [==============================] - 73s 37ms/step - loss: 0.1436 - acc: 0.9401 - val_loss: 0.2032 - val_acc: 0.9231
# Epoch 100/100
# 1970/1970 [==============================] - 72s 37ms/step - loss: 0.1315 - acc: 0.9482 - val_loss: 0.2158 - val_acc: 0.9181
# /home/scanner-ml/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:6: FutureWarning: pd.ewm_mean is deprecated for ndarrays and will be removed in a future version
#
# /home/scanner-ml/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:7: FutureWarning: pd.ewm_mean is deprecated for ndarrays and will be removed in a future version
#   import sys
# /home/scanner-ml/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:19: FutureWarning: pd.ewm_mean is deprecated for ndarrays and will be removed in a future version
# /home/scanner-ml/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:20: FutureWarning: pd.ewm_mean is deprecated for ndarrays and will be removed in a future version
# 3478/3478 [==============================] - 12s 3ms/step

# %%
samp = vgg_samp[1]
adamka = optimizers.Adam(lr=1e-4, decay=1e-6)
ddd_vgg_model = DDD_VGG_model(input_shape=(31,31,8,1))
ddd_vgg_model.compile(optimizer=adamka, loss='binary_crossentropy', metrics=['accuracy'])
vgg_samp_hist.append(ddd_vgg_model.fit(X_ddd_train, Y_train, epochs = 100, batch_size = 128, validation_split=1-samp, verbose=1))
    #print('training on ', vgg_samp_hist[-1].params['samples'], ' samples')
plot_hist(vgg_samp_hist[-1].history, span=5, names=['acc_'+str(round(samp*100))+'perc','loss_'+str(round(samp*100))+'perc'])
pred_samp.append(ddd_vgg_model.evaluate(X_ddd_test, Y_test))
# Out:
# conv1	 (?, 15, 15, 4, 64)
# conv2	 (?, 7, 7, 2, 128)
# conv3	 (?, 3, 3, 1, 256)
# conv4	 (?, 2, 2, 1, 256)
# Train on 3940 samples, validate on 15763 samples
# Epoch 1/100
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1322     try:
# -> 1323       return fn(*args)
#    1324     except errors.OpError as e:
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1301                                    feed_dict, fetch_list, target_list,
# -> 1302                                    status, run_metadata)
#    1303
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/errors_impl.py in __exit__(self, type_arg, value_arg, traceback_arg)
#     472             compat.as_text(c_api.TF_Message(self.status.status)),
# --> 473             c_api.TF_GetCode(self.status.status))
#     474     # Delete the underlying status object from memory otherwise it stays alive
#
# ResourceExhaustedError: OOM when allocating tensor with shape[128,64,31,31,8]
# 	 [[Node: training_1/Adam/gradients/pool1_1/MaxPool3D_grad/MaxPool3DGrad = MaxPool3DGrad[T=DT_FLOAT, TInput=DT_FLOAT, _class=["loc:@pool1_1/MaxPool3D"], data_format="NDHWC", ksize=[1, 2, 2, 2, 1], padding="VALID", strides=[1, 2, 2, 2, 1], _device="/job:localhost/replica:0/task:0/device:GPU:0"](activation_5/Relu, pool1_1/MaxPool3D, training_1/Adam/gradients/conv2_1/convolution_grad/Conv3DBackpropInputV2)]]
#
# During handling of the above exception, another exception occurred:
#
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-13-f534a0422bc6> in <module>()
#       3 ddd_vgg_model = DDD_VGG_model(input_shape=(31,31,8,1))
#       4 ddd_vgg_model.compile(optimizer=adamka, loss='binary_crossentropy', metrics=['accuracy'])
# ----> 5 vgg_samp_hist.append(ddd_vgg_model.fit(X_ddd_train, Y_train, epochs = 100, batch_size = 128, validation_split=1-samp, verbose=1))
#       6     #print('training on ', vgg_samp_hist[-1].params['samples'], ' samples')
#       7 plot_hist(vgg_samp_hist[-1].history, span=5, names=['acc_'+str(round(samp*100))+'perc','loss_'+str(round(samp*100))+'perc'])
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1710                               initial_epoch=initial_epoch,
#    1711                               steps_per_epoch=steps_per_epoch,
# -> 1712                               validation_steps=validation_steps)
#    1713
#    1714     def evaluate(self, x=None, y=None,
#
# ~/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1233                         ins_batch[i] = ins_batch[i].toarray()
#    1234
# -> 1235                     outs = f(ins_batch)
#    1236                     if not isinstance(outs, list):
#    1237                         outs = [outs]
#
# ~/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2473         session = get_session()
#    2474         updated = session.run(fetches=fetches, feed_dict=feed_dict,
# -> 2475                               **self.session_kwargs)
#    2476         return updated[:len(self.outputs)]
#    2477
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     887     try:
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#     891         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1118     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1119       results = self._do_run(handle, final_targets, final_fetches,
# -> 1120                              feed_dict_tensor, options, run_metadata)
#    1121     else:
#    1122       results = []
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1315     if handle is None:
#    1316       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1317                            options, run_metadata)
#    1318     else:
#    1319       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1334         except KeyError:
#    1335           pass
# -> 1336       raise type(e)(node_def, op, message)
#    1337
#    1338   def _extend_graph(self):
#
# ResourceExhaustedError: OOM when allocating tensor with shape[128,64,31,31,8]
# 	 [[Node: training_1/Adam/gradients/pool1_1/MaxPool3D_grad/MaxPool3DGrad = MaxPool3DGrad[T=DT_FLOAT, TInput=DT_FLOAT, _class=["loc:@pool1_1/MaxPool3D"], data_format="NDHWC", ksize=[1, 2, 2, 2, 1], padding="VALID", strides=[1, 2, 2, 2, 1], _device="/job:localhost/replica:0/task:0/device:GPU:0"](activation_5/Relu, pool1_1/MaxPool3D, training_1/Adam/gradients/conv2_1/convolution_grad/Conv3DBackpropInputV2)]]
#
# Caused by op 'training_1/Adam/gradients/pool1_1/MaxPool3D_grad/MaxPool3DGrad', defined at:
#   File "/home/scanner-ml/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/home/scanner-ml/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/home/scanner-ml/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/scanner-ml/anaconda3/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/home/scanner-ml/anaconda3/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 478, in start
#     self.io_loop.start()
#   File "/home/scanner-ml/anaconda3/lib/python3.6/site-packages/zmq/eventloop/ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "/home/scanner-ml/anaconda3/lib/python3.6/site-packages/tornado/ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "/home/scanner-ml/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/scanner-ml/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "/home/scanner-ml/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/home/scanner-ml/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "/home/scanner-ml/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/home/scanner-ml/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/home/scanner-ml/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/home/scanner-ml/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/home/scanner-ml/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/scanner-ml/anaconda3/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/scanner-ml/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2728, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/home/scanner-ml/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2850, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/home/scanner-ml/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2910, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-13-f534a0422bc6>", line 5, in <module>
#     vgg_samp_hist.append(ddd_vgg_model.fit(X_ddd_train, Y_train, epochs = 100, batch_size = 128, validation_split=1-samp, verbose=1))
#   File "/home/scanner-ml/anaconda3/lib/python3.6/site-packages/keras/engine/training.py", line 1689, in fit
#     self._make_train_function()
#   File "/home/scanner-ml/anaconda3/lib/python3.6/site-packages/keras/engine/training.py", line 990, in _make_train_function
#     loss=self.total_loss)
#   File "/home/scanner-ml/anaconda3/lib/python3.6/site-packages/keras/legacy/interfaces.py", line 91, in wrapper
#     return func(*args, **kwargs)
#   File "/home/scanner-ml/anaconda3/lib/python3.6/site-packages/keras/optimizers.py", line 440, in get_updates
#     grads = self.get_gradients(loss, params)
#   File "/home/scanner-ml/anaconda3/lib/python3.6/site-packages/keras/optimizers.py", line 78, in get_gradients
#     grads = K.gradients(loss, params)
#   File "/home/scanner-ml/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py", line 2512, in gradients
#     return tf.gradients(loss, variables, colocate_gradients_with_ops=True)
#   File "/home/scanner-ml/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py", line 581, in gradients
#     grad_scope, op, func_call, lambda: grad_fn(op, *out_grads))
#   File "/home/scanner-ml/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py", line 353, in _MaybeCompile
#     return grad_fn()  # Exit early
#   File "/home/scanner-ml/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py", line 581, in <lambda>
#     grad_scope, op, func_call, lambda: grad_fn(op, *out_grads))
#   File "/home/scanner-ml/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/nn_grad.py", line 155, in _MaxPool3DGrad
#     data_format=op.get_attr("data_format"))
#   File "/home/scanner-ml/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/gen_nn_ops.py", line 2939, in _max_pool3d_grad
#     data_format=data_format, name=name)
#   File "/home/scanner-ml/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py", line 787, in _apply_op_helper
#     op_def=op_def)
#   File "/home/scanner-ml/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 2956, in create_op
#     op_def=op_def)
#   File "/home/scanner-ml/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 1470, in __init__
#     self._traceback = self._graph._extract_stack()  # pylint: disable=protected-access
#
# ...which was originally created as op 'pool1_1/MaxPool3D', defined at:
#   File "/home/scanner-ml/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
# [elided 18 identical lines from previous traceback]
#   File "/home/scanner-ml/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2910, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-13-f534a0422bc6>", line 3, in <module>
#     ddd_vgg_model = DDD_VGG_model(input_shape=(31,31,8,1))
#   File "<ipython-input-9-b6462edc58a7>", line 10, in DDD_VGG_model
#     X = MaxPooling3D(name='pool1')(X)
#   File "/home/scanner-ml/anaconda3/lib/python3.6/site-packages/keras/engine/topology.py", line 617, in __call__
#     output = self.call(inputs, **kwargs)
#   File "/home/scanner-ml/anaconda3/lib/python3.6/site-packages/keras/layers/pooling.py", line 327, in call
#     data_format=self.data_format)
#   File "/home/scanner-ml/anaconda3/lib/python3.6/site-packages/keras/layers/pooling.py", line 385, in _pooling_function
#     padding, data_format, pool_mode='max')
#   File "/home/scanner-ml/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py", line 3703, in pool3d
#     data_format=tf_data_format)
#   File "/home/scanner-ml/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/gen_nn_ops.py", line 2870, in max_pool3d
#     padding=padding, data_format=data_format, name=name)
#   File "/home/scanner-ml/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py", line 787, in _apply_op_helper
#     op_def=op_def)
#   File "/home/scanner-ml/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 2956, in create_op
#     op_def=op_def)
#   File "/home/scanner-ml/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py", line 1470, in __init__
#     self._traceback = self._graph._extract_stack()  # pylint: disable=protected-access
#
# ResourceExhaustedError (see above for traceback): OOM when allocating tensor with shape[128,64,31,31,8]
# 	 [[Node: training_1/Adam/gradients/pool1_1/MaxPool3D_grad/MaxPool3DGrad = MaxPool3DGrad[T=DT_FLOAT, TInput=DT_FLOAT, _class=["loc:@pool1_1/MaxPool3D"], data_format="NDHWC", ksize=[1, 2, 2, 2, 1], padding="VALID", strides=[1, 2, 2, 2, 1], _device="/job:localhost/replica:0/task:0/device:GPU:0"](activation_5/Relu, pool1_1/MaxPool3D, training_1/Adam/gradients/conv2_1/convolution_grad/Conv3DBackpropInputV2)]]

# %%
samp = vgg_samp[2]
adamka = optimizers.Adam(lr=1e-4, decay=1e-6)
ddd_vgg_model = DDD_VGG_model(input_shape=(31,31,8,1))
ddd_vgg_model.compile(optimizer=adamka, loss='binary_crossentropy', metrics=['accuracy'])
vgg_samp_hist.append(ddd_vgg_model.fit(X_ddd_train, Y_train, epochs = 100, batch_size = 128, validation_split=1-samp, verbose=1))
    #print('training on ', vgg_samp_hist[-1].params['samples'], ' samples')
plot_hist(vgg_samp_hist[-1].history, span=5, names=['acc_'+str(round(samp*100))+'perc','loss_'+str(round(samp*100))+'perc'])
pred_samp.append(ddd_vgg_model.evaluate(X_ddd_test, Y_test))

# %%
samp = vgg_samp[3]
adamka = optimizers.Adam(lr=1e-4, decay=1e-6)
ddd_vgg_model = DDD_VGG_model(input_shape=(31,31,8,1))
ddd_vgg_model.compile(optimizer=adamka, loss='binary_crossentropy', metrics=['accuracy'])
vgg_samp_hist.append(ddd_vgg_model.fit(X_ddd_train, Y_train, epochs = 100, batch_size = 128, validation_split=1-samp, verbose=1))
    #print('training on ', vgg_samp_hist[-1].params['samples'], ' samples')
plot_hist(vgg_samp_hist[-1].history, span=5, names=['acc_'+str(round(samp*100))+'perc','loss_'+str(round(samp*100))+'perc'])
pred_samp.append(ddd_vgg_model.evaluate(X_ddd_test, Y_test))
